# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 592

# %%
#Print list of cities
#cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Counter for city number
counter = 1

# Lists to hold data
city_name = []
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

print('------------------------------')
print('Start Data Retrieval')
print('------------------------------')

for city in cities:
    response = requests.get(query_url + city).json() 
    try: 
        city_name.append(response['name'])
        lat.append(response['coord']['lat'])   
        lng.append(response['coord']['lon'])            
        max_temp.append(response['main']['temp_max'])              
        humidity.append(response['main']['humidity']) 
        cloudiness.append(response['clouds']['all'])   
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        print(f'City number {counter} of {len(cities)} | {city} information was added.')
        counter = counter + 1
    except KeyError:
        print(f'Missing data in city number {counter} of {len(cities)} | {city} information was NOT added.')
        counter = counter + 1
        pass
# Out:
# ------------------------------
# Start Data Retrieval
# ------------------------------
# City number 1 of 592 | kumluca information was added.
# City number 2 of 592 | narsaq information was added.
# City number 3 of 592 | kapaa information was added.
# City number 4 of 592 | arraial do cabo information was added.
# City number 5 of 592 | kajaani information was added.
# City number 6 of 592 | urumqi information was added.
# City number 7 of 592 | beringovskiy information was added.
# City number 8 of 592 | souillac information was added.
# City number 9 of 592 | bethel information was added.
# City number 10 of 592 | cabo san lucas information was added.
# City number 11 of 592 | thompson information was added.
# City number 12 of 592 | rikitea information was added.
# City number 13 of 592 | port alfred information was added.
# City number 14 of 592 | georgetown information was added.
# Missing data in city number 15 of 592 | taolanaro information was NOT added.
# City number 16 of 592 | kjollefjord information was added.
# City number 17 of 592 | alamogordo information was added.
# City number 18 of 592 | cidreira information was added.
# City number 19 of 592 | jamestown information was added.
# City number 20 of 592 | hobyo information was added.
# City number 21 of 592 | college information was added.
# Missing data in city number 22 of 592 | nizhneyansk information was NOT added.
# City number 23 of 592 | albany information was added.
# City number 24 of 592 | tandil information was added.
# City number 25 of 592 | khatanga information was added.
# City number 26 of 592 | khanpur information was added.
# City number 27 of 592 | nanortalik information was added.
# City number 28 of 592 | esna information was added.
# City number 29 of 592 | naze information was added.
# City number 30 of 592 | hobart information was added.
# City number 31 of 592 | berlevag information was added.
# City number 32 of 592 | henties bay information was added.
# City number 33 of 592 | bredasdorp information was added.
# City number 34 of 592 | itapipoca information was added.
# City number 35 of 592 | grand forks information was added.
# City number 36 of 592 | maues information was added.
# City number 37 of 592 | codrington information was added.
# City number 38 of 592 | port elizabeth information was added.
# City number 39 of 592 | meulaboh information was added.
# City number 40 of 592 | ancud information was added.
# City number 41 of 592 | upernavik information was added.
# City number 42 of 592 | dikson information was added.
# City number 43 of 592 | punta arenas information was added.
# City number 44 of 592 | ardakan information was added.
# City number 45 of 592 | ketchikan information was added.
# City number 46 of 592 | jacksonville information was added.
# City number 47 of 592 | busselton information was added.
# City number 48 of 592 | carnarvon information was added.
# City number 49 of 592 | prince rupert information was added.
# City number 50 of 592 | jijiga information was added.
# City number 51 of 592 | pringsewu information was added.
# City number 52 of 592 | palkino information was added.
# Missing data in city number 53 of 592 | belushya guba information was NOT added.
# City number 54 of 592 | joao monlevade information was added.
# City number 55 of 592 | nueva helvecia information was added.
# City number 56 of 592 | gladstone information was added.
# City number 57 of 592 | saint-philippe information was added.
# City number 58 of 592 | cape town information was added.
# City number 59 of 592 | ipoh information was added.
# City number 60 of 592 | phalaborwa information was added.
# City number 61 of 592 | silifke information was added.
# City number 62 of 592 | qaanaaq information was added.
# City number 63 of 592 | naron information was added.
# City number 64 of 592 | atuona information was added.
# City number 65 of 592 | airai information was added.
# City number 66 of 592 | mataura information was added.
# City number 67 of 592 | barrow information was added.
# City number 68 of 592 | new norfolk information was added.
# City number 69 of 592 | los llanos de aridane information was added.
# City number 70 of 592 | avera information was added.
# City number 71 of 592 | ust-tsilma information was added.
# Missing data in city number 72 of 592 | tabiauea information was NOT added.
# City number 73 of 592 | yulara information was added.
# City number 74 of 592 | sabang information was added.
# City number 75 of 592 | castro information was added.
# City number 76 of 592 | saskylakh information was added.
# City number 77 of 592 | carauari information was added.
# City number 78 of 592 | torbay information was added.
# City number 79 of 592 | talnakh information was added.
# City number 80 of 592 | novoorsk information was added.
# Missing data in city number 81 of 592 | sentyabrskiy information was NOT added.
# City number 82 of 592 | tiksi information was added.
# City number 83 of 592 | longyearbyen information was added.
# City number 84 of 592 | vestmannaeyjar information was added.
# Missing data in city number 85 of 592 | illoqqortoormiut information was NOT added.
# Missing data in city number 86 of 592 | galiwinku information was NOT added.
# Missing data in city number 87 of 592 | tidore information was NOT added.
# City number 88 of 592 | innisfail information was added.
# City number 89 of 592 | cayenne information was added.
# City number 90 of 592 | bluff information was added.
# City number 91 of 592 | nemuro information was added.
# City number 92 of 592 | avarua information was added.
# City number 93 of 592 | lorengau information was added.
# City number 94 of 592 | marshall information was added.
# City number 95 of 592 | vaini information was added.
# City number 96 of 592 | kolpashevo information was added.
# City number 97 of 592 | sao jose da coroa grande information was added.
# City number 98 of 592 | galiakot information was added.
# City number 99 of 592 | belogorsk information was added.
# City number 100 of 592 | maniitsoq information was added.
# City number 101 of 592 | poum information was added.
# City number 102 of 592 | norman wells information was added.
# City number 103 of 592 | vao information was added.
# City number 104 of 592 | ribeira grande information was added.
# City number 105 of 592 | kodiak information was added.
# City number 106 of 592 | san patricio information was added.
# City number 107 of 592 | mahebourg information was added.
# City number 108 of 592 | ushuaia information was added.
# City number 109 of 592 | barcelos information was added.
# City number 110 of 592 | bambous virieux information was added.
# Missing data in city number 111 of 592 | cazaje information was NOT added.
# City number 112 of 592 | namibe information was added.
# City number 113 of 592 | caravelas information was added.
# City number 114 of 592 | gornopravdinsk information was added.
# City number 115 of 592 | gamba information was added.
# City number 116 of 592 | maumere information was added.
# City number 117 of 592 | salalah information was added.
# City number 118 of 592 | bengkulu information was added.
# City number 119 of 592 | dingle information was added.
# City number 120 of 592 | aksarka information was added.
# City number 121 of 592 | phulji information was added.
# City number 122 of 592 | yellowknife information was added.
# City number 123 of 592 | aykhal information was added.
# City number 124 of 592 | hithadhoo information was added.
# City number 125 of 592 | wodonga information was added.
# City number 126 of 592 | dalby information was added.
# City number 127 of 592 | pundaguitan information was added.
# City number 128 of 592 | bang saphan information was added.
# City number 129 of 592 | chuy information was added.
# City number 130 of 592 | cockburn town information was added.
# City number 131 of 592 | hilo information was added.
# City number 132 of 592 | chokurdakh information was added.
# City number 133 of 592 | constantine information was added.
# City number 134 of 592 | geraldton information was added.
# City number 135 of 592 | imbituba information was added.
# City number 136 of 592 | ilebo information was added.
# City number 137 of 592 | bronnoysund information was added.
# City number 138 of 592 | petropavlovka information was added.
# City number 139 of 592 | katsuura information was added.
# City number 140 of 592 | srednekolymsk information was added.
# City number 141 of 592 | tadine information was added.
# Missing data in city number 142 of 592 | saryshagan information was NOT added.
# City number 143 of 592 | khor information was added.
# City number 144 of 592 | porbandar information was added.
# City number 145 of 592 | sibolga information was added.
# City number 146 of 592 | broome information was added.
# City number 147 of 592 | ulaangom information was added.
# City number 148 of 592 | ponta do sol information was added.
# City number 149 of 592 | kropotkin information was added.
# City number 150 of 592 | hermanus information was added.
# City number 151 of 592 | tuktoyaktuk information was added.
# City number 152 of 592 | alugan information was added.
# City number 153 of 592 | pevek information was added.
# Missing data in city number 154 of 592 | grand river south east information was NOT added.
# City number 155 of 592 | limbang information was added.
# City number 156 of 592 | keetmanshoop information was added.
# City number 157 of 592 | vuktyl information was added.
# City number 158 of 592 | potiskum information was added.
# City number 159 of 592 | dhankuta information was added.
# City number 160 of 592 | aklavik information was added.
# City number 161 of 592 | harlingen information was added.
# City number 162 of 592 | saint-pierre information was added.
# Missing data in city number 163 of 592 | vaitupu information was NOT added.
# City number 164 of 592 | rivera information was added.
# Missing data in city number 165 of 592 | haibowan information was NOT added.
# City number 166 of 592 | amarwara information was added.
# City number 167 of 592 | skjervoy information was added.
# City number 168 of 592 | clinton information was added.
# City number 169 of 592 | esperance information was added.
# City number 170 of 592 | porosozero information was added.
# City number 171 of 592 | biankouma information was added.
# City number 172 of 592 | tilichiki information was added.
# City number 173 of 592 | lempaala information was added.
# City number 174 of 592 | trelew information was added.
# City number 175 of 592 | raga information was added.
# City number 176 of 592 | sobolevo information was added.
# City number 177 of 592 | sidi ali information was added.
# Missing data in city number 178 of 592 | tumannyy information was NOT added.
# City number 179 of 592 | sarankhola information was added.
# City number 180 of 592 | kastamonu information was added.
# City number 181 of 592 | vanderhoof information was added.
# City number 182 of 592 | mira information was added.
# City number 183 of 592 | trinidad information was added.
# City number 184 of 592 | mount gambier information was added.
# City number 185 of 592 | karlskoga information was added.
# City number 186 of 592 | mangan information was added.
# City number 187 of 592 | fethiye information was added.
# City number 188 of 592 | husavik information was added.
# City number 189 of 592 | nizhniy kuranakh information was added.
# City number 190 of 592 | pangody information was added.
# City number 191 of 592 | chicama information was added.
# Missing data in city number 192 of 592 | tsihombe information was NOT added.
# City number 193 of 592 | dwarka information was added.
# City number 194 of 592 | mar del plata information was added.
# City number 195 of 592 | hirara information was added.
# City number 196 of 592 | winnemucca information was added.
# City number 197 of 592 | sungaipenuh information was added.
# City number 198 of 592 | puerto ayora information was added.
# City number 199 of 592 | luderitz information was added.
# City number 200 of 592 | pala information was added.
# City number 201 of 592 | saint anthony information was added.
# City number 202 of 592 | makat information was added.
# City number 203 of 592 | butaritari information was added.
# Missing data in city number 204 of 592 | artyk information was NOT added.
# City number 205 of 592 | antsohihy information was added.
# City number 206 of 592 | madang information was added.
# City number 207 of 592 | songjianghe information was added.
# City number 208 of 592 | mahibadhoo information was added.
# Missing data in city number 209 of 592 | lolua information was NOT added.
# City number 210 of 592 | east london information was added.
# City number 211 of 592 | mehamn information was added.
# City number 212 of 592 | margate information was added.
# Missing data in city number 213 of 592 | maghama information was NOT added.
# City number 214 of 592 | honiara information was added.
# City number 215 of 592 | derzhavinsk information was added.
# City number 216 of 592 | ostrovnoy information was added.
# City number 217 of 592 | sitka information was added.
# City number 218 of 592 | kaitangata information was added.
# City number 219 of 592 | trimbak information was added.
# City number 220 of 592 | porto novo information was added.
# City number 221 of 592 | warri information was added.
# City number 222 of 592 | port hardy information was added.
# City number 223 of 592 | lufilufi information was added.
# City number 224 of 592 | saint-joseph information was added.
# City number 225 of 592 | lima information was added.
# City number 226 of 592 | sao gabriel da cachoeira information was added.
# City number 227 of 592 | coquimbo information was added.
# City number 228 of 592 | tabriz information was added.
# City number 229 of 592 | saldanha information was added.
# City number 230 of 592 | iqaluit information was added.
# City number 231 of 592 | port-gentil information was added.
# City number 232 of 592 | payo information was added.
# City number 233 of 592 | bayji information was added.
# City number 234 of 592 | verkhnyaya inta information was added.
# City number 235 of 592 | nikolskoye information was added.
# City number 236 of 592 | kidal information was added.
# City number 237 of 592 | quatre cocos information was added.
# Missing data in city number 238 of 592 | bur gabo information was NOT added.
# City number 239 of 592 | paamiut information was added.
# City number 240 of 592 | mango information was added.
# Missing data in city number 241 of 592 | saleaula information was NOT added.
# City number 242 of 592 | belaya information was added.
# Missing data in city number 243 of 592 | urdzhar information was NOT added.
# City number 244 of 592 | saint george information was added.
# City number 245 of 592 | bandar-e lengeh information was added.
# Missing data in city number 246 of 592 | amderma information was NOT added.
# City number 247 of 592 | bodden town information was added.
# City number 248 of 592 | nuqui information was added.
# City number 249 of 592 | freital information was added.
# City number 250 of 592 | nabire information was added.
# City number 251 of 592 | wajima information was added.
# City number 252 of 592 | malindi information was added.
# City number 253 of 592 | ugoofaaru information was added.
# City number 254 of 592 | calvinia information was added.
# City number 255 of 592 | kosino information was added.
# City number 256 of 592 | yaan information was added.
# City number 257 of 592 | pisco information was added.
# City number 258 of 592 | fortuna information was added.
# City number 259 of 592 | tatarbunary information was added.
# Missing data in city number 260 of 592 | halalo information was NOT added.
# City number 261 of 592 | tasiilaq information was added.
# City number 262 of 592 | carbonia information was added.
# City number 263 of 592 | neuquen information was added.
# City number 264 of 592 | taormina information was added.
# City number 265 of 592 | yumen information was added.
# City number 266 of 592 | serpa information was added.
# City number 267 of 592 | hofn information was added.
# City number 268 of 592 | yantal information was added.
# City number 269 of 592 | ahuimanu information was added.
# Missing data in city number 270 of 592 | barentsburg information was NOT added.
# City number 271 of 592 | constitucion information was added.
# City number 272 of 592 | chernaya kholunitsa information was added.
# City number 273 of 592 | sakrand information was added.
# City number 274 of 592 | praxedis guerrero information was added.
# City number 275 of 592 | provideniya information was added.
# City number 276 of 592 | puerto leguizamo information was added.
# City number 277 of 592 | grindavik information was added.
# City number 278 of 592 | yar-sale information was added.
# City number 279 of 592 | ulaanbaatar information was added.
# City number 280 of 592 | lebu information was added.
# City number 281 of 592 | dryden information was added.
# City number 282 of 592 | hovd information was added.
# City number 283 of 592 | kununurra information was added.
# City number 284 of 592 | plettenberg bay information was added.
# City number 285 of 592 | jerusalem information was added.
# City number 286 of 592 | salina information was added.
# City number 287 of 592 | itacare information was added.
# City number 288 of 592 | goderich information was added.
# City number 289 of 592 | san mateo del mar information was added.
# City number 290 of 592 | gazojak information was added.
# City number 291 of 592 | nelson bay information was added.
# City number 292 of 592 | saint-louis information was added.
# City number 293 of 592 | kurumkan information was added.
# City number 294 of 592 | nalut information was added.
# City number 295 of 592 | lompoc information was added.
# City number 296 of 592 | nsanje information was added.
# City number 297 of 592 | kirakira information was added.
# City number 298 of 592 | adrar information was added.
# City number 299 of 592 | tartus information was added.
# City number 300 of 592 | oak ridge information was added.
# City number 301 of 592 | kosh-agach information was added.
# City number 302 of 592 | grants information was added.
# City number 303 of 592 | ambilobe information was added.
# City number 304 of 592 | paita information was added.
# City number 305 of 592 | vostok information was added.
# City number 306 of 592 | benguela information was added.
# City number 307 of 592 | rocha information was added.
# City number 308 of 592 | port lincoln information was added.
# City number 309 of 592 | vardo information was added.
# City number 310 of 592 | severo-kurilsk information was added.
# City number 311 of 592 | mokhsogollokh information was added.
# City number 312 of 592 | maningrida information was added.
# Missing data in city number 313 of 592 | labutta information was NOT added.
# City number 314 of 592 | polovinnoye information was added.
# City number 315 of 592 | khorixas information was added.
# City number 316 of 592 | lillooet information was added.
# City number 317 of 592 | najran information was added.
# City number 318 of 592 | launceston information was added.
# City number 319 of 592 | tessalit information was added.
# City number 320 of 592 | lagoa information was added.
# Missing data in city number 321 of 592 | mendahara information was NOT added.
# City number 322 of 592 | coahuayana information was added.
# City number 323 of 592 | flin flon information was added.
# City number 324 of 592 | qasigiannguit information was added.
# City number 325 of 592 | belyy yar information was added.
# City number 326 of 592 | mitsamiouli information was added.
# City number 327 of 592 | tsagveri information was added.
# City number 328 of 592 | nhulunbuy information was added.
# City number 329 of 592 | svetlaya information was added.
# City number 330 of 592 | lakselv information was added.
# City number 331 of 592 | walvis bay information was added.
# City number 332 of 592 | severo-yeniseyskiy information was added.
# City number 333 of 592 | aasiaat information was added.
# City number 334 of 592 | saint andrews information was added.
# City number 335 of 592 | paicandu information was added.
# City number 336 of 592 | kiunga information was added.
# City number 337 of 592 | half moon bay information was added.
# City number 338 of 592 | haines junction information was added.
# City number 339 of 592 | maebaru information was added.
# City number 340 of 592 | sinnamary information was added.
# City number 341 of 592 | soyo information was added.
# City number 342 of 592 | emerald information was added.
# Missing data in city number 343 of 592 | marcona information was NOT added.
# Missing data in city number 344 of 592 | mys shmidta information was NOT added.
# City number 345 of 592 | sorland information was added.
# City number 346 of 592 | taoudenni information was added.
# City number 347 of 592 | richards bay information was added.
# City number 348 of 592 | camalu information was added.
# City number 349 of 592 | sao joao da barra information was added.
# City number 350 of 592 | storforshei information was added.
# City number 351 of 592 | bin qirdan information was added.
# City number 352 of 592 | hambantota information was added.
# City number 353 of 592 | camacha information was added.
# City number 354 of 592 | ixtapa information was added.
# City number 355 of 592 | port augusta information was added.
# City number 356 of 592 | aloleng information was added.
# Missing data in city number 357 of 592 | palabuhanratu information was NOT added.
# City number 358 of 592 | balkhash information was added.
# City number 359 of 592 | denpasar information was added.
# City number 360 of 592 | priiskovyy information was added.
# City number 361 of 592 | gimli information was added.
# City number 362 of 592 | dudinka information was added.
# City number 363 of 592 | dzilam gonzalez information was added.
# City number 364 of 592 | puerto colombia information was added.
# City number 365 of 592 | san cristobal information was added.
# City number 366 of 592 | kanigoro information was added.
# City number 367 of 592 | aquin information was added.
# City number 368 of 592 | radviliskis information was added.
# City number 369 of 592 | kaeo information was added.
# City number 370 of 592 | tarakan information was added.
# City number 371 of 592 | bonavista information was added.
# City number 372 of 592 | doka information was added.
# City number 373 of 592 | malanje information was added.
# City number 374 of 592 | nchelenge information was added.
# City number 375 of 592 | bathsheba information was added.
# City number 376 of 592 | namatanai information was added.
# City number 377 of 592 | ashti information was added.
# City number 378 of 592 | kendari information was added.
# City number 379 of 592 | saint-augustin information was added.
# City number 380 of 592 | lerwick information was added.
# City number 381 of 592 | demba information was added.
# City number 382 of 592 | beian information was added.
# Missing data in city number 383 of 592 | tawzar information was NOT added.
# City number 384 of 592 | wonthaggi information was added.
# City number 385 of 592 | ossora information was added.
# City number 386 of 592 | fare information was added.
# City number 387 of 592 | pauini information was added.
# City number 388 of 592 | ovsyanka information was added.
# City number 389 of 592 | pirapozinho information was added.
# City number 390 of 592 | el tigre information was added.
# City number 391 of 592 | emba information was added.
# City number 392 of 592 | rio bueno information was added.
# City number 393 of 592 | russell information was added.
# City number 394 of 592 | kalmunai information was added.
# City number 395 of 592 | chernyshevsk information was added.
# City number 396 of 592 | fort nelson information was added.
# City number 397 of 592 | cairns information was added.
# City number 398 of 592 | marsh harbour information was added.
# City number 399 of 592 | mangrol information was added.
# City number 400 of 592 | lapua information was added.
# City number 401 of 592 | loandjili information was added.
# City number 402 of 592 | novaya malykla information was added.
# City number 403 of 592 | karatau information was added.
# City number 404 of 592 | mumford information was added.
# Missing data in city number 405 of 592 | barawe information was NOT added.
# City number 406 of 592 | leningradskiy information was added.
# City number 407 of 592 | catuday information was added.
# City number 408 of 592 | alenquer information was added.
# Missing data in city number 409 of 592 | attawapiskat information was NOT added.
# City number 410 of 592 | laurel information was added.
# City number 411 of 592 | hay river information was added.
# City number 412 of 592 | mugur-aksy information was added.
# City number 413 of 592 | bugarama information was added.
# City number 414 of 592 | haapsalu information was added.
# City number 415 of 592 | sivaki information was added.
# City number 416 of 592 | la asuncion information was added.
# City number 417 of 592 | ahipara information was added.
# City number 418 of 592 | sechura information was added.
# City number 419 of 592 | hasaki information was added.
# City number 420 of 592 | alice springs information was added.
# City number 421 of 592 | sakaiminato information was added.
# City number 422 of 592 | monrovia information was added.
# City number 423 of 592 | sumkino information was added.
# City number 424 of 592 | pacifica information was added.
# City number 425 of 592 | havoysund information was added.
# City number 426 of 592 | galesburg information was added.
# City number 427 of 592 | fairbanks information was added.
# City number 428 of 592 | gizo information was added.
# City number 429 of 592 | guymon information was added.
# Missing data in city number 430 of 592 | bolshoye soldatskoye information was NOT added.
# City number 431 of 592 | newport information was added.
# City number 432 of 592 | micheweni information was added.
# City number 433 of 592 | pacific grove information was added.
# City number 434 of 592 | remiremont information was added.
# City number 435 of 592 | sines information was added.
# City number 436 of 592 | nantucket information was added.
# City number 437 of 592 | ulladulla information was added.
# City number 438 of 592 | nakhon phanom information was added.
# City number 439 of 592 | saint-francois information was added.
# City number 440 of 592 | cherskiy information was added.
# City number 441 of 592 | acajutla information was added.
# City number 442 of 592 | oranjestad information was added.
# City number 443 of 592 | burkburnett information was added.
# City number 444 of 592 | belo jardim information was added.
# City number 445 of 592 | jiaozuo information was added.
# City number 446 of 592 | inhambane information was added.
# City number 447 of 592 | zhanaozen information was added.
# City number 448 of 592 | makakilo city information was added.
# City number 449 of 592 | gat information was added.
# City number 450 of 592 | kedrovyy information was added.
# City number 451 of 592 | juruti information was added.
# City number 452 of 592 | jackson information was added.
# City number 453 of 592 | chara information was added.
# City number 454 of 592 | okha information was added.
# City number 455 of 592 | semey information was added.
# City number 456 of 592 | namuac information was added.
# City number 457 of 592 | saint john information was added.
# City number 458 of 592 | cedar city information was added.
# City number 459 of 592 | vila velha information was added.
# Missing data in city number 460 of 592 | kawana waters information was NOT added.
# City number 461 of 592 | roma information was added.
# City number 462 of 592 | santa isabel information was added.
# City number 463 of 592 | boden information was added.
# City number 464 of 592 | pailon information was added.
# City number 465 of 592 | butte information was added.
# Missing data in city number 466 of 592 | bandar maharani information was NOT added.
# City number 467 of 592 | tomigusuku information was added.
# City number 468 of 592 | pipraich information was added.
# City number 469 of 592 | tuatapere information was added.
# City number 470 of 592 | katherine information was added.
# City number 471 of 592 | port hedland information was added.
# City number 472 of 592 | vangaindrano information was added.
# City number 473 of 592 | kinablangan information was added.
# City number 474 of 592 | banaba information was added.
# City number 475 of 592 | krasnyy information was added.
# City number 476 of 592 | barga information was added.
# City number 477 of 592 | umm kaddadah information was added.
# City number 478 of 592 | chagoda information was added.
# City number 479 of 592 | babu information was added.
# City number 480 of 592 | vila franca do campo information was added.
# City number 481 of 592 | goure information was added.
# City number 482 of 592 | tiznit information was added.
# City number 483 of 592 | caohai information was added.
# City number 484 of 592 | reitz information was added.
# Missing data in city number 485 of 592 | tanshui information was NOT added.
# City number 486 of 592 | gorontalo information was added.
# City number 487 of 592 | kuminskiy information was added.
# City number 488 of 592 | rincon information was added.
# City number 489 of 592 | kitimat information was added.
# City number 490 of 592 | concordia information was added.
# Missing data in city number 491 of 592 | samusu information was NOT added.
# City number 492 of 592 | serebryansk information was added.
# City number 493 of 592 | tokur information was added.
# City number 494 of 592 | tevriz information was added.
# Missing data in city number 495 of 592 | opobo information was NOT added.
# City number 496 of 592 | charlestown information was added.
# City number 497 of 592 | bosaso information was added.
# City number 498 of 592 | san martin information was added.
# City number 499 of 592 | lavrentiya information was added.
# City number 500 of 592 | puerto escondido information was added.
# City number 501 of 592 | iracoubo information was added.
# City number 502 of 592 | korla information was added.
# City number 503 of 592 | isangel information was added.
# City number 504 of 592 | ubajara information was added.
# City number 505 of 592 | lubin information was added.
# City number 506 of 592 | miles city information was added.
# City number 507 of 592 | port moresby information was added.
# City number 508 of 592 | xining information was added.
# City number 509 of 592 | methoni information was added.
# City number 510 of 592 | bilibino information was added.
# City number 511 of 592 | wajir information was added.
# City number 512 of 592 | acapulco information was added.
# City number 513 of 592 | kavieng information was added.
# City number 514 of 592 | lincoln information was added.
# City number 515 of 592 | den helder information was added.
# City number 516 of 592 | hare bay information was added.
# City number 517 of 592 | west wendover information was added.
# City number 518 of 592 | maua information was added.
# Missing data in city number 519 of 592 | phan rang information was NOT added.
# City number 520 of 592 | sindou information was added.
# City number 521 of 592 | sanmenxia information was added.
# City number 522 of 592 | khasan information was added.
# City number 523 of 592 | daund information was added.
# City number 524 of 592 | erenhot information was added.
# City number 525 of 592 | sampit information was added.
# City number 526 of 592 | baracoa information was added.
# City number 527 of 592 | elesbao veloso information was added.
# City number 528 of 592 | necochea information was added.
# City number 529 of 592 | alta floresta information was added.
# City number 530 of 592 | huoqiu information was added.
# City number 531 of 592 | sokoni information was added.
# Missing data in city number 532 of 592 | ji-parana information was NOT added.
# City number 533 of 592 | kupang information was added.
# City number 534 of 592 | ingham information was added.
# City number 535 of 592 | luanda information was added.
# City number 536 of 592 | kanniyakumari information was added.
# City number 537 of 592 | harper information was added.
# City number 538 of 592 | fort abbas information was added.
# City number 539 of 592 | pyapon information was added.
# City number 540 of 592 | abalak information was added.
# City number 541 of 592 | kargasok information was added.
# City number 542 of 592 | charters towers information was added.
# City number 543 of 592 | foam lake information was added.
# City number 544 of 592 | mikhaylovka information was added.
# City number 545 of 592 | bonanza information was added.
# City number 546 of 592 | tunduma information was added.
# City number 547 of 592 | praia da vitoria information was added.
# City number 548 of 592 | yerbogachen information was added.
# City number 549 of 592 | burnie information was added.
# Missing data in city number 550 of 592 | mullaitivu information was NOT added.
# City number 551 of 592 | champerico information was added.
# City number 552 of 592 | sakakah information was added.
# City number 553 of 592 | filingue information was added.
# City number 554 of 592 | zyryanovsk information was added.
# City number 555 of 592 | petropavlovsk-kamchatskiy information was added.
# City number 556 of 592 | saurimo information was added.
# City number 557 of 592 | pangnirtung information was added.
# City number 558 of 592 | tazovskiy information was added.
# City number 559 of 592 | kruisfontein information was added.
# City number 560 of 592 | salamiyah information was added.
# City number 561 of 592 | mecca information was added.
# City number 562 of 592 | faanui information was added.
# City number 563 of 592 | zverinogolovskoye information was added.
# City number 564 of 592 | sao felix do xingu information was added.
# City number 565 of 592 | port blair information was added.
# City number 566 of 592 | logon information was added.
# City number 567 of 592 | tromso information was added.
# City number 568 of 592 | huarmey information was added.
# City number 569 of 592 | manokwari information was added.
# City number 570 of 592 | matagami information was added.
# City number 571 of 592 | kachug information was added.
# Missing data in city number 572 of 592 | kuche information was NOT added.
# City number 573 of 592 | ibotirama information was added.
# City number 574 of 592 | wenling information was added.
# City number 575 of 592 | sal rei information was added.
# City number 576 of 592 | kailua information was added.
# City number 577 of 592 | egvekinot information was added.
# City number 578 of 592 | piacabucu information was added.
# City number 579 of 592 | mayo information was added.
# City number 580 of 592 | fort smith information was added.
# City number 581 of 592 | yarada information was added.
# City number 582 of 592 | kieta information was added.
# City number 583 of 592 | victoria information was added.
# City number 584 of 592 | tefe information was added.
# City number 585 of 592 | chico information was added.
# City number 586 of 592 | muisne information was added.
# City number 587 of 592 | bubaque information was added.
# City number 588 of 592 | benemerito de las americas information was added.
# City number 589 of 592 | clyde river information was added.
# City number 590 of 592 | shaowu information was added.
# Missing data in city number 591 of 592 | umzimvubu information was NOT added.
# City number 592 of 592 | santa marta information was added.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame(
    {"City Name": city_name,
     "Latitude": lat,
     "Longitude": lng,
     "Max Temp": max_temp,
     "Humidity": humidity,
     "Cloudiness": cloudiness,
     "Wind Speed": wind_speed,
     "Country": country,
     "Date": date
    }
)
city_data_df.head()
# Out:
#          City Name  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0          Kumluca     36.37      30.29      31.6        41           0
# 1           Narsaq     60.92     -46.05       9.0        93          75
# 2            Kapaa     22.08    -159.32      26.0        78          90
# 3  Arraial do Cabo    -22.97     -42.03      23.0        56          75
# 4          Kajaani     64.23      27.73      13.0        76         100
#
#    Wind Speed Country        Date
# 0        4.04      TR  1594396904
# 1        1.50      GL  1594396907
# 2        7.20      US  1594396909
# 3        3.10      BR  1594396912
# 4        4.10      FI  1594396913

# %%
city_data_df.to_csv("city_data.csv", index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
too_humid = city_data_df["Humidity"] > 100
too_humid.value_counts()
# Out:
# False    549
# Name: Humidity, dtype: int64

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# %matplotlib notebook

# Import Dependencies
import matplotlib.pyplot as plt
import numpy as np

city_data_df.plot(kind="scatter", x="Latitude", y="Max Temp", marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs Max Temperature (7/10/20)")
plt.xlabel("City Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.tight_layout()
plt.savefig("lat_max_temp.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
city_data_df.plot(kind="scatter", x="Latitude", y="Humidity", marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs Humidity (%) (7/10/20)")
plt.xlabel("City Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.tight_layout()
plt.savefig("lat_humidity.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
city_data_df.plot(kind="scatter", x="Latitude", y="Cloudiness", marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs Cloudiness (%) (7/10/20)")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.tight_layout()
plt.savefig("lat_cloudiness.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
city_data_df.plot(kind="scatter", x="Latitude", y="Wind Speed", marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs Wind Speed (mph) (7/10/20)")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.tight_layout()
plt.savefig("lat_wind_speed.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northern_hemisphere = city_data_df.loc[(city_data_df["Latitude"] >= 0), :]
northern_hemisphere.head()
# Out:
#   City Name  Latitude  Longitude  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Kumluca     36.37      30.29      31.6        41           0        4.04
# 1    Narsaq     60.92     -46.05       9.0        93          75        1.50
# 2     Kapaa     22.08    -159.32      26.0        78          90        7.20
# 4   Kajaani     64.23      27.73      13.0        76         100        4.10
# 5    Ürümqi     43.80      87.60      27.0        32         100        4.00
#
#   Country        Date
# 0      TR  1594396904
# 1      GL  1594396907
# 2      US  1594396909
# 4      FI  1594396913
# 5      CN  1594396916

# %%
# %matplotlib notebook

# Import Dependencies
import matplotlib.pyplot as plt
import numpy as np

# Create the plot
northern_hemisphere.plot(kind="scatter", x="Latitude", y="Max Temp", marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Northern Hemisphere: City Latitude vs Max Temperature (7/10/20)")
plt.xlabel("City Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.tight_layout()

# Linear regression
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()

plt.savefig("north_lat_max_temp.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.5389498791354754

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_hemisphere = city_data_df.loc[(city_data_df["Latitude"] < 0), :]
southern_hemisphere.head()
# Out:
#           City Name  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 3   Arraial do Cabo    -22.97     -42.03     23.00        56          75
# 7          Souillac    -20.52      57.52     22.00        64          40
# 11          Rikitea    -23.12    -134.97     19.49        65          41
# 12      Port Alfred    -33.59      26.89     16.11        90          74
# 16         Cidreira    -30.18     -50.21     15.47        70           0
#
#     Wind Speed Country        Date
# 3         3.10      BR  1594396912
# 7         9.80      MU  1594396924
# 11        8.55      PF  1594396933
# 12        7.03      ZA  1594396655
# 16        7.38      BR  1594396663

# %%
# Create the plot
southern_hemisphere.plot(kind="scatter", x="Latitude", y="Max Temp", marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Southern Hemisphere: City Latitude vs Max Temperature (7/10/20)")
plt.xlabel("City Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.tight_layout()

# Linear regression
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()

plt.savefig("south_lat_max_temp.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.7569161532719475

# %%
print("OBSERVATIONS FOR TEMPERATURE AND LATITUDE")
print("--------------------------------")
print("Based on these two plots, there is a correlation between cities closer to the equator having higher maximum temperatures compared to those farther away from the equator.")
# Out:
# OBSERVATIONS FOR TEMPERATURE AND LATITUDE
# --------------------------------
# Based on these two plots, there is a correlation between cities closer to the equator having higher maximum temperatures compared to those farther away from the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create the plot
northern_hemisphere.plot(kind="scatter", x="Latitude", y="Humidity", marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Northern Hemisphere: City Latitude vs Humidity (%) (7/10/20)")
plt.xlabel("City Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.tight_layout()

# Linear regression
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()

plt.savefig("north_lat_humidity.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.008040825966949827

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create the plot
southern_hemisphere.plot(kind="scatter", x="Latitude", y="Humidity", marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Southern Hemisphere: City Latitude vs Humidity (%) (7/10/20)")
plt.xlabel("City Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.tight_layout()

# Linear regression
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()

plt.savefig("south_lat_humid.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.021568783881867927

# %%
print("OBSERVATIONS FOR HUMIDITY AND LATITUDE")
print("--------------------------------")
print("There are no correlations between humidity levels and the distance from the equator.")
# Out:
# OBSERVATIONS FOR HUMIDITY AND LATITUDE
# --------------------------------
# There are no correlations between humidity levels and the distance from the equator.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create the plot
northern_hemisphere.plot(kind="scatter", x="Latitude", y="Cloudiness", marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Northern Hemisphere: City Latitude vs Cloudiness (%) (7/10/20)")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.tight_layout()

# Linear regression
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()

plt.savefig("north_lat_cloudiness.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.007066859478870897

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create the plot
southern_hemisphere.plot(kind="scatter", x="Latitude", y="Cloudiness", marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Southern Hemisphere: City Latitude vs Cloudiness (%) (7/10/20)")
plt.xlabel("City Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.tight_layout()

# Linear regression
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()

plt.savefig("south_lat_cloudiness.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.0209377108321318

# %%
print("OBSERVATIONS FOR CLOUDINESS AND LATITUDE")
print("--------------------------------")
print("There are no correlations between cloudiness levels and the distance from the equator.")
# Out:
# OBSERVATIONS FOR CLOUDINESS AND LATITUDE
# --------------------------------
# There are no correlations between cloudiness levels and the distance from the equator.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create the plot
northern_hemisphere.plot(kind="scatter", x="Latitude", y="Wind Speed", marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Northern Hemisphere: City Latitude vs Wind Speed (mph) (7/10/20)")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.tight_layout()

# Linear regression
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()

plt.savefig("north_lat_wind_speed.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.0006535611322313781

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create the plot
southern_hemisphere.plot(kind="scatter", x="Latitude", y="Wind Speed", marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("Southern Hemisphere: City Latitude vs Wind Speed (mph) (7/10/20)")
plt.xlabel("City Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.tight_layout()

# Linear regression
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()

plt.savefig("south_lat_wind_speed.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# The r-squared is: 0.01223743229768018

# %%
print("OBSERVATIONS FOR WIND SPEED AND LATITUDE")
print("--------------------------------")
print("There are no correlations between wind speed and the distance from the equator.")
# Out:
# OBSERVATIONS FOR WIND SPEED AND LATITUDE
# --------------------------------
# There are no correlations between wind speed and the distance from the equator.
